# %% [markdown]
# Authors: Ishan Prasad and Sourjyamoy Barman\
# Date: 8 July 2023\
# Project: Lyrics guessing game\
# This is were we look at the data before making the game - clean it if desired

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd

# %%
# load dataset into pandas dataframe
data = pd.read_csv("raw_songs.csv")
data
# Out:
#                               Name             Artist  \
# 0        Imagine - Remastered 2010        John Lennon
# 1           A Whiter Shade Of Pale       Procol Harum
# 2                    My Sweet Lord    George Harrison
# 3            God Only Knows - Mono     The Beach Boys
# 4       Bridge Over Troubled Water  Simon & Garfunkel
# ..                             ...                ...
# 794              Thinking out Loud         Ed Sheeran
# 795                          Sorry      Justin Bieber
# 796  Lean On (feat. MØ & DJ Snake)        Major Lazer
# 797              Take Me To Church             Hozier
# 798                           King      Years & Years
#
#                                        Album  Popularity  \
# 0                                    Imagine          79
# 1                     A Whiter Shade Of Pale           0
# 2          All Things Must Pass (Remastered)           0
# 3    Pet Sounds (Original Mono & Stereo Mix)          67
# ...

# %%
# drop popularity column - not necessary
data = data.drop(['Popularity'], axis = 1)
data
# Out:
#                               Name             Artist  \
# 0        Imagine - Remastered 2010        John Lennon
# 1           A Whiter Shade Of Pale       Procol Harum
# 2                    My Sweet Lord    George Harrison
# 3            God Only Knows - Mono     The Beach Boys
# 4       Bridge Over Troubled Water  Simon & Garfunkel
# ..                             ...                ...
# 794              Thinking out Loud         Ed Sheeran
# 795                          Sorry      Justin Bieber
# 796  Lean On (feat. MØ & DJ Snake)        Major Lazer
# 797              Take Me To Church             Hozier
# 798                           King      Years & Years
#
#                                        Album  \
# 0                                    Imagine
# 1                     A Whiter Shade Of Pale
# 2          All Things Must Pass (Remastered)
# 3    Pet Sounds (Original Mono & Stereo Mix)
# 4                 Bridge Over Troubled Water
# ...

# %%
data["Lyrics"][40]
# Out:
# '43 ContributorsFor What It’s Worth Lyrics[Verse 1]\nThere\'s something happening here\nBut what it is ain\'t exactly clear\nThere\'s a man with a gun over there\nA-telling me I got to beware\n\n[Chorus]\nI think it\'s time we stop\nChildren, what\'s that sound?\nEverybody look what\'s going down\n\n[Verse 2]\nThere\'s battle lines being drawn\nAnd nobody\'s right if everybody\'s wrong\nYoung people speaking their minds\nAre gettin\' so much resistance from behind\n\n[Chorus]\nIt\'s time we stop\nHey, what\'s that sound?\nEverybody look what\'s going down\n\n[Verse 3]\nWhat a field day for the heat (Ooh-ooh-ooh)\nA thousand people in the street (Ooh-ooh-ooh)\nSinging songs and a-carryin\' signs (Ooh-ooh-ooh)\nMostly say, "Hooray for our side" (Ooh-ooh-ooh)\nYou might also like[Chorus]\nIt\'s time we stopped\nHey, what\'s that sound?\nEverybody look what\'s going down\n\n[Verse 4]\nParanoia strikes deep\nInto your life, it will creep\nIt starts when you\'re always afraid\nStep out of 
# ...

# %%
count = 0
nums = []
for i in range(len(data["Lyrics"])):
    if i != 74:
        if data['Name'][i].casefold().split("-")[0] not in data["Lyrics"][i].casefold():
            print(i, data['Name'][i])
            nums.append(i)
            count += 1
print(count)
# Out:
# 5 Bohemian Rhapsody - Remastered 2011
# 6 Stairway to Heaven - Remaster
# 9 “Heroes” - Single Version; 2014 Remaster
# 11 Johnny B. Goode - Single Version
# 17 Life on Mars? - 2015 Remaster
# 18 You Can't Always Get What You Want - Single Version
# 24 A Day In The Life - Remastered
# 26 (I Can't Get No) Satisfaction - Mono Version / Remastered 2002
# 27 No Woman, No Cry - Live At The Lyceum, London/1975
# 28 Waterloo Sunset - Mono Version
# 34 Heart of Gold - 2009 Remaster
# 40 For What It's Worth
# 42 Jump - 2015 Remaster
# 43 Love Me Tender - From the 20th Century-Fox CinemaScope Production, "Love Me Tender"
# 45 You Send Me - Remastered
# 49 Smoke On The Water - Remastered 2012
# 50 All You Need Is Love - Remastered
# 51 (We're Gonna) Rock Around The Clock - Single Version
# 53 You Really Got Me - Remastered
# 54 Baby Love - Juke Box Single Version
# 57 Mrs. Robinson - From "The Graduate" Soundtrack
# 59 Here Comes The Sun - Remastered
# 65 Nothing Compares 2 U - 2009 Remaster
# ...

# %%
for each in nums:
    data = data.drop(each)
data.shape
# Out:
# (660, 4)

# %%
data = data.drop(0)

# %%
data = data.reset_index()
data
# Out:
#      index                        Name             Artist  \
# 0        1      A Whiter Shade Of Pale       Procol Harum
# 1        2               My Sweet Lord    George Harrison
# 2        3       God Only Knows - Mono     The Beach Boys
# 3        4  Bridge Over Troubled Water  Simon & Garfunkel
# 4        7    All Along the Watchtower       Jimi Hendrix
# ..     ...                         ...                ...
# 654    793                       Sugar           Maroon 5
# 655    794           Thinking out Loud         Ed Sheeran
# 656    795                       Sorry      Justin Bieber
# 657    797           Take Me To Church             Hozier
# 658    798                        King      Years & Years
#
#                                        Album  \
# 0                     A Whiter Shade Of Pale
# 1          All Things Must Pass (Remastered)
# 2    Pet Sounds (Original Mono & Stereo Mix)
# 3                 Bridge Over Troubled Water
# ...

# %%
for k in range(len(data["Lyrics"])):
        if " " not in data['Name'][k]:
                print(k, data['Name'][k])
# Out:
# 7 Alive
# 9 Paranoid
# 15 One
# 51 Wannabe
# 56 Lovefool
# 66 Twisted
# 80 Lady
# 101 Words
# 104 Hush
# 106 Firestarter
# 111 Spaceman
# 119 Flowers
# 120 Daylight
# 123 TQG
# 125 Tattoo
# 126 PRC
# 127 BESO
# 134 Anti-Hero
# 137 AMG
# 141 Acróstico
# 147 Moonlight
# 151 Starboy
# 155 People
# 158 FLOWER
# 159 Mockingbird
# 160 Frágil
# 162 Obsessed
# 164 Fictional
# 165 Daylight
# 167 Tattoo
# 169 Jericho
# 176 TABU.
# 181 Promise
# 182 Bye
# 185 Frágil
# 186 Perfume
# 187 Solo
# 188 Watergun
# 191 Évidemment
# 192 アイドル
# 193 Bridges
# 197 Unicorn
# 200 Gladiator
# 209 Higher
# 217 Mockingbird
# 223 Beautiful
# 224 Superman
# 237 Legacy
# 241 Survival
# 247 Forever
# 248 Berzerk
# 250 Renegade
# 254 Wreckage
# 255 Daylight
# 256 Chemical
# 259 Gold
# 260 Curtains
# 263 REACT
# 264 HAPPY
# 266 TRUSTFALL
# 267 People
# 269 Players
# 272 ceilings
# 276 Karma
# 277 Heaven
# 278 Here
# 287 Flowers
# 295 Peaches
# 296 Meltdown
# 297 Rush
# 302 Bops
# 303 Strange
# 320 SNAP
# 326 TQG
# ...

# %%
data['Lyrics'][654]
# Out:
# "86 ContributorsTranslationsPortuguêsFrançaisSugar Lyrics[Verse 1]\nI'm hurting, baby, I'm broken down\nI need your loving, loving, I need it now\nWhen I'm without you, I'm something weak\nYou got me begging, begging, I'm on my knees\n\n[Pre-Chorus]\nI don't wanna be needing your love\nI just wanna be deep in your love\nAnd it's killing me when you're away\nOoh, baby\n'Cause I really don't care where you are\nI just wanna be there where you are\nAnd I gotta get one little taste\n\n[Chorus]\nYour sugar, yes, please\nWon't you come and put it down on me?\nI'm right here, 'cause I need\nLittle love, a little sympathy\nYeah, you show me good loving, make it alright\nNeed a little sweetness in my life\nYour sugar, yes, please\nWon't you come and put it down on me?\n\n[Verse 2]\nBabe, my broken pieces, you pick them up\nDon't leave me hanging, hanging, come give me some\nWhen I'm without you, I'm so insecure\nYou are the one thing, one thing I'm living for\nYou might also like[Pre-Chorus]\
# ...

# %%
data['Lyrics'][0]
